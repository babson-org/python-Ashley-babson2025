# %% [markdown]
# # map()
#
# The **map()** function applies a function to every item in an iterable and returns an iterator of results.
#
# **Syntax:**
# ```python
# map(function, iterable)
# ```
#
# Here we use a **named function**, not a lambda.

# %%
def square(x):
    return x * x

nums = [1, 2, 3, 4]
# map returns a map object, you need to convert it to a list
squares = list(map(square, nums))
print(squares)

# %% [markdown]
# ### Exercises
# 1. Use map() with a named function to convert a list of strings to integers.
# 2. Use map() with a named function to lowercase a list of words.
# 3. Write a function `triple(n)` and use map() to apply it to a list of numbers.

# %%
#map(function,iterable)
#use map() with a named function to convert a list of strings to integers
def convert(txt):
    return int(txt)

string_list = ['1','2','3']
my_ints = list(map(convert,string_list))
print(my_ints)

#use map() with name function to lowercase a list of words
def make_lower(x): 
    return x.lower()

words = ['THE', 'CAT', 'IS', 'ORANGE']
lower_words = list(map(make_lower, words))
print(lower_words)

#write a triple(n) function and use map() to apply to a list of numbers 
def triple(nxt):
    return int(n)

nums = [1,2,3,4]
trips = list(map(triple,nums))
print(trips)

# %% [markdown]
# # filter()
#
# The **filter()** function keeps only items for which a function returns **True**.
#
# **Syntax:**
# ```python
# filter(function, iterable)
# ```
#
# Using a **named function instead of lambda**.

# %%
def is_even(n):
    return n % 2 == 0

nums = [1, 2, 3, 4, 5, 6]
# filter returns a filter object, you need to convert it to a list
evens = list(filter(is_even, nums))
print(evens)

# %% [markdown]
# ### Exercises
# 1. Write a function `is_odd(n)` and use filter() to extract odd numbers.
# 2. Write a function that returns True only for strings with length > 3.
# 3. Write a function that returns False for empty strings and use filter() to remove them.

# %%
#1
def is_odd(n):
    return n % 2 != 0
nums = [1,2,3,4,5,6]
odds = list(filter(is_odd, nums))
print(odds)

#2
def return_t (n):
    return len(n) > 3

wrd = ['now', 'is', 'the', 'time', 'for', 'all', 'good',]
long_words = list(filter(return_t, wrd))
print(long_words)

#3
#def empty(txt): FINISH THIS FOR PRACTICE 
    #if len(txt) > 0

#words =
# Out:
# [1, 3, 5]
# ['time', 'good']

# %% [markdown]
# # reduce()
#
# The **reduce()** function applies a function cumulatively to items in an iterable,
# reducing them to a single value.
#
# **Syntax:**
# ```python
# from functools import reduce
# reduce(function, iterable)
# ```
#
# Here we use a named function, not lambda.

# %%
from functools import reduce

def add(a, b):
    return a + b

nums = [1, 2, 3, 4]
total = reduce(add, nums)
print(total)
# Out:
# 10

# %% [markdown]
# ### Exercises
# 1. Write a function `multiply(a, b)` and use reduce() to compute the product of a list.
# 2. Write a function to compare two strings and return the longer one; use reduce() to find the longest string.
# 3. Write a function that concatenates two strings with a space in between and reduce a list of words into a sentence.

# %%
#1
def mult(a,b):
    return a*b 
nums = [1,2,3,4]
total = reduce(mult,nums)
print(total)

#2
def comp(a,b):
    if a > b:
        return a 

wrds = ['The', 'Cats', 'are', 'Orange']
longest = reduce(comp,wrds)
print(longest)

#3
# Out:
# 24
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 14
#      11         return a
#      13 wrds = ['The', 'Cats', 'are', 'Orange']
# ---> 14 longest = reduce(comp,wrds)
#      15 print(longest)
#
# Cell In[9], line 10, in comp(a, b)
#       9 def comp(a,b):
# ---> 10     if a > b:
#      11         return a
#
# TypeError: '>' not supported between instances of 'NoneType' and 'str'
